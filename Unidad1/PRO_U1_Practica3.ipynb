# %% [markdown]
# <a href="https://colab.research.google.com/github/JoseGabriel-ITD/Probabilidad-y-Estadistica/blob/main/Unidad1/PRO_U1_Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad y estadística**
#
# ## Unidad 1
#
# ### **Practica 3. Máximo, mínimo, Rango y dispersión de datos.**
#
# ### Facilitador: *Dr. José Gabriel Rodríguez Rivas*
#
# ### Alumno:  _____________

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1 = []
for i in range(100):
    numero_aleatorio = round( random.uniform(50, 100), 2 )
    fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [75.09, 72.95, 81.54, 57.59, 71.25, 82.33, 74.27, 85.48, 53.74, 53.1, 86.72, 57.46, 71.57, 65.05, 79.93, 79.7, 96.01, 84.38, 82.93, 98.15, 53.68, 76.45, 98.49, 93.33, 81.41, 61.73, 67.9, 51.6, 79.93, 65.43, 55.86, 57.24, 82.47, 55.09, 78.45, 95.29, 94.35, 66.77, 58.71, 86.9, 98.56, 76.16, 97.21, 63.96, 91.24, 61.1, 85.86, 87.16, 54.08, 52.86, 63.41, 69.02, 98.1, 69.2, 91.92, 79.27, 56.82, 94.86, 70.92, 84.86, 53.79, 63.29, 98.36, 66.46, 75.12, 80.42, 82.75, 71.2, 57.7, 77.65, 63.84, 98.42, 91.05, 82.97, 93.15, 76.85, 62.0, 50.63, 70.94, 63.83, 91.76, 63.39, 76.65, 86.88, 56.34, 85.89, 58.52, 65.22, 80.31, 50.33, 85.44, 59.93, 71.42, 56.26, 77.58, 84.81, 73.19, 85.22, 88.33, 50.69]

# %%
fabrica2 = []
for i in range(100):
    numero_aleatorio2 = round( random.uniform(50, 100), 2 )
    fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [67.63, 89.22, 74.52, 89.1, 50.97, 65.27, 87.44, 67.83, 80.51, 67.36, 82.28, 76.91, 68.69, 55.62, 66.2, 52.53, 83.12, 90.22, 73.94, 63.84, 53.21, 67.88, 98.93, 88.87, 88.78, 63.25, 99.63, 56.98, 88.32, 85.68, 67.78, 96.58, 78.38, 82.92, 62.27, 64.01, 88.36, 56.46, 87.93, 79.55, 51.06, 50.08, 65.14, 51.79, 66.83, 90.62, 75.04, 93.88, 88.28, 52.11, 74.03, 81.71, 80.13, 78.08, 90.23, 91.94, 81.71, 81.57, 79.72, 69.8, 92.54, 61.3, 74.32, 83.41, 79.88, 61.01, 55.68, 60.75, 78.88, 71.77, 52.54, 86.07, 88.39, 77.71, 81.11, 56.01, 75.03, 77.73, 90.9, 88.25, 60.5, 98.36, 56.02, 99.28, 64.49, 78.32, 92.05, 92.15, 74.65, 90.98, 93.38, 50.73, 50.56, 96.27, 95.11, 57.9, 77.05, 91.52, 57.49, 92.73]

# %% [markdown]
# ##  Maximo, mínimo, y rango  <a id='id4'> </a>

# %%
maximo1 = max(fabrica1)
minimo1 = min(fabrica1)
rango1 = maximo1 - minimo1
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print( "Estadistica descriptiva de la Fabrica 1 \n", "Media =", media1,
     "\n Mediana =", mediana1, "\n Moda =", moda1, "\n Maximo = ", maximo1,
     "\n Minimo =", minimo1, "\n Rango =", rango1)
# Out:
# Estadistica descriptiva de la Fabrica 1
#  Media = 74.4547
#  Mediana = 75.64
#  Moda = 79.93
#  Maximo =  98.56
#  Minimo = 50.33
#  Rango = 48.230000000000004

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo1 - minimo2
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print( "Estadistica descriptiva de la Fabrica 2 \n", "Media =", media2,
     "\n Mediana =", mediana2, "\n Moda =", moda2, "\n Maximo = ", maximo2,
     "\n Minimo =", minimo2, "\n Rango =", rango2)
# Out:
# Estadistica descriptiva de la Fabrica 2
#  Media = 75.6554
#  Mediana = 77.905
#  Moda = 81.71
#  Maximo =  99.63
#  Minimo = 50.08
#  Rango = 48.480000000000004

# %% [markdown]
# ## Dispersión de los datos   <a id='id5'> </a>

# %%
desviacion_estandar_fabrica1 = stdev(fabrica1)
print(desviacion_estandar_fabrica1)
# Out:
# 14.249644933021022

# %%
desviacion_estandar_fabrica2 = stdev(fabrica2)
print(desviacion_estandar_fabrica2)
# Out:
# 14.38766428843708

# %%
plt.figure(figsize = (8,6) )
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'Media={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana1:.2f}')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda1:.2f}')
plt.axvline(media1 - desviacion_estandar_fabrica1, color='black', linestyle='dashed',
            linewidth=2, label=f'Desv. Estándar ={desviacion_estandar_fabrica1:.2f}')
plt.axvline(media1 + desviacion_estandar_fabrica1, color='black', linestyle='dashed',
            linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.figure(figsize = (8,6) )
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'Media={media2:.2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana2:.2f}')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda2:.2f}')

plt.axvline(media2 - desviacion_estandar_fabrica2, color='black', linestyle='dashed',
            linewidth=2, label=f'Desv. Estándar ={desviacion_estandar_fabrica2:.2f}')
plt.axvline(media2 + desviacion_estandar_fabrica2, color='black', linestyle='dashed',
            linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 2")
plt.legend()
plt.show()

# %% [markdown]
# ## Densidad  <a id="id6"> </a>

# %%
import seaborn as sns

# %%
# La densidad gráfica es una forma de visualizar la distribución de datos en
# un intervalo o período de tiempo continuo.
# Se basa en un histograma que usa el suavizado de kernel para trazar valores,
# lo que permite obtener distribuciones más suaves al reducir el ruido.
# Una curva de densidad muestra la ubicación de la media y la mediana de una distribución.

sns.histplot( x = fabrica1, kde = True, kde_kws = {'bw_adjust': 0.5}, bins = 10 )
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# # **Practica 4: Tablas de frecuencias**  <a id="id7"> </a>

# %%
# basado en el LIBRO estadistica para administracion pagina 12
# creamos una lista vacia  que representa la edad de 100 personas
import random
edades = []
# Hacemos un ciclo para generar 100  numeros aleatorios qe representan la edad de las personas
for i in range(100):
  # generamos un numero aleatorio con la funcion randint y lo guardamos en la variable
  # numero_aleatorio
  numero_aleatorio = random.randint( 18, 70)
  # Agregamos el numero aleatorio a la lista de valores
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [20, 50, 48, 35, 37, 54, 59, 63, 36, 46, 40, 52, 20, 20, 55, 65, 40, 30, 37, 48, 19, 32, 39, 53, 31, 49, 49, 29, 68, 66, 62, 60, 70, 52, 52, 28, 47, 29, 21, 68, 64, 35, 54, 40, 30, 29, 42, 56, 45, 47, 47, 29, 37, 31, 29, 21, 47, 69, 47, 42, 22, 19, 34, 44, 46, 23, 53, 37, 41, 66, 45, 44, 27, 55, 52, 56, 42, 60, 44, 33, 47, 46, 63, 43, 43, 52, 38, 44, 31, 60, 61, 41, 46, 28, 19, 41, 24, 42, 27, 26]

# %%
import pandas as pd

# %%
# Crear un DataFrame de pandas con los números aleatorios
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    20
# 1    50
# 2    48
# 3    35
# 4    37

# %%
# Calcular la tabla de distribución de frecuencias
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

# Imprimir la tabla de distribución de frecuencias
print("Tabla de Distribución de Frecuencias:")
tabla_frecuencias
# Out:
# Tabla de Distribución de Frecuencias:
#     Edad  Frecuencia
# 9     19           3
# 7     20           3
# 15    21           2
# 37    22           1
# 34    23           1
# 30    24           1
# 46    26           1
# 16    27           2
# 17    28           2
# 1     29           5
# 23    30           2
# 12    31           3
# 41    32           1
# 33    33           1
# 29    34           1
# 24    35           2
# 38    36           1
# 3     37           4
# 32    38           1
# 43    39           1
# 10    40           3
# 11    41           3
# 5     42           4
# 18    43           2
# 4     44           4
# 14    45           2
# 6     46           4
# 0     47           6
# 22    48           2
# 21    49           2
# 45    50           1
# 2     52           5
# 28    53           2
# 25    54           2
# 26    55           2
# 13    56           2
# 35    59           1
# 8     60           3
# 31    61           1
# 44    62           1
# 27    63           2
# 39    64           1
# 40    65           1
# 20    66           2
# 19    68           2
# 36    69           1
# 42    70           1

# %%
tabla_frecuencias['Frec Relativa'] = tabla_frecuencias['Frecuencia'] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 9     19           3           0.03
# 7     20           3           0.03
# 15    21           2           0.02
# 37    22           1           0.01
# 34    23           1           0.01
# 30    24           1           0.01
# 46    26           1           0.01
# 16    27           2           0.02
# 17    28           2           0.02
# 1     29           5           0.05
# 23    30           2           0.02
# 12    31           3           0.03
# 41    32           1           0.01
# 33    33           1           0.01
# 29    34           1           0.01
# 24    35           2           0.02
# 38    36           1           0.01
# 3     37           4           0.04
# 32    38           1           0.01
# 43    39           1           0.01
# 10    40           3           0.03
# 11    41           3           0.03
# 5     42           4           0.04
# 18    43           2           0.02
# 4     44           4           0.04
# 14    45           2           0.02
# 6     46           4           0.04
# 0     47           6           0.06
# 22    48           2           0.02
# 21    49           2           0.02
# 45    50           1           0.01
# 2     52           5           0.05
# 28    53           2           0.02
# 25    54           2           0.02
# 26    55           2           0.02
# 13    56           2           0.02
# 35    59           1           0.01
# 8     60           3           0.03
# 31    61           1           0.01
# 44    62           1           0.01
# 27    63           2           0.02
# 39    64           1           0.01
# 40    65           1           0.01
# 20    66           2           0.02
# 19    68           2           0.02
# 36    69           1           0.01
# 42    70           1           0.01

# %%
tabla_frecuencias['Frec Porcentual'] = tabla_frecuencias['Frecuencia'] / 100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 9     19           3           0.03              3.0
# 7     20           3           0.03              3.0
# 15    21           2           0.02              2.0
# 37    22           1           0.01              1.0
# 34    23           1           0.01              1.0
# 30    24           1           0.01              1.0
# 46    26           1           0.01              1.0
# 16    27           2           0.02              2.0
# 17    28           2           0.02              2.0
# 1     29           5           0.05              5.0
# 23    30           2           0.02              2.0
# 12    31           3           0.03              3.0
# 41    32           1           0.01              1.0
# 33    33           1           0.01              1.0
# 29    34           1           0.01              1.0
# 24    35           2           0.02              2.0
# 38    36           1           0.01              1.0
# 3     37           4           0.04              4.0
# 32    38           1           0.01              1.0
# 43    39           1           0.01              1.0
# 10    40           3           0.03              3.0
# 11    41           3           0.03              3.0
# 5     42           4           0.04              4.0
# 18    43           2           0.02              2.0
# 4     44           4           0.04              4.0
# 14    45           2           0.02              2.0
# 6     46           4           0.04              4.0
# 0     47           6           0.06              6.0
# 22    48           2           0.02              2.0
# 21    49           2           0.02              2.0
# 45    50           1           0.01              1.0
# 2     52           5           0.05              5.0
# 28    53           2           0.02              2.0
# 25    54           2           0.02              2.0
# 26    55           2           0.02              2.0
# 13    56           2           0.02              2.0
# 35    59           1           0.01              1.0
# 8     60           3           0.03              3.0
# 31    61           1           0.01              1.0
# 44    62           1           0.01              1.0
# 27    63           2           0.02              2.0
# 39    64           1           0.01              1.0
# 40    65           1           0.01              1.0
# 20    66           2           0.02              2.0
# 19    68           2           0.02              2.0
# 36    69           1           0.01              1.0
# 42    70           1           0.01              1.0

# %%
tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 9     19           3           0.03              3.0               3
# 7     20           3           0.03              3.0               6
# 15    21           2           0.02              2.0               8
# 37    22           1           0.01              1.0               9
# 34    23           1           0.01              1.0              10
# 30    24           1           0.01              1.0              11
# 46    26           1           0.01              1.0              12
# 16    27           2           0.02              2.0              14
# 17    28           2           0.02              2.0              16
# 1     29           5           0.05              5.0              21
# 23    30           2           0.02              2.0              23
# 12    31           3           0.03              3.0              26
# 41    32           1           0.01              1.0              27
# 33    33           1           0.01              1.0              28
# 29    34           1           0.01              1.0              29
# 24    35           2           0.02              2.0              31
# 38    36           1           0.01              1.0              32
# 3     37           4           0.04              4.0              36
# 32    38           1           0.01              1.0              37
# 43    39           1           0.01              1.0              38
# 10    40           3           0.03              3.0              41
# 11    41           3           0.03              3.0              44
# 5     42           4           0.04              4.0              48
# 18    43           2           0.02              2.0              50
# 4     44           4           0.04              4.0              54
# 14    45           2           0.02              2.0              56
# 6     46           4           0.04              4.0              60
# 0     47           6           0.06              6.0              66
# 22    48           2           0.02              2.0              68
# 21    49           2           0.02              2.0              70
# 45    50           1           0.01              1.0              71
# 2     52           5           0.05              5.0              76
# 28    53           2           0.02              2.0              78
# 25    54           2           0.02              2.0              80
# 26    55           2           0.02              2.0              82
# 13    56           2           0.02              2.0              84
# 35    59           1           0.01              1.0              85
# 8     60           3           0.03              3.0              88
# 31    61           1           0.01              1.0              89
# 44    62           1           0.01              1.0              90
# 27    63           2           0.02              2.0              92
# 39    64           1           0.01              1.0              93
# 40    65           1           0.01              1.0              94
# 20    66           2           0.02              2.0              96
# 19    68           2           0.02              2.0              98
# 36    69           1           0.01              1.0              99
# 42    70           1           0.01              1.0             100

# %% [markdown]
# ## Regla de sturges  <a id="id8"> </a>
#
# 1. Es una regla que sirve para calcular el número de clases o intervalos idóneo en los que se debe dividir un conjunto de datos.
# 2. Establece que **el número de clases es igual a uno más el logaritmo en base dos del número total de datos**.
#
# $
# c = 1 + log _2 (N)
# $
#
# donde $N$  es el tamaño de la muestra.

# %%
# Importamos la librería math de funciones matemáticas
import math

# %%
# Volvemos a usar la lista edades
print(edades)
# Out:
# [20, 50, 48, 35, 37, 54, 59, 63, 36, 46, 40, 52, 20, 20, 55, 65, 40, 30, 37, 48, 19, 32, 39, 53, 31, 49, 49, 29, 68, 66, 62, 60, 70, 52, 52, 28, 47, 29, 21, 68, 64, 35, 54, 40, 30, 29, 42, 56, 45, 47, 47, 29, 37, 31, 29, 21, 47, 69, 47, 42, 22, 19, 34, 44, 46, 23, 53, 37, 41, 66, 45, 44, 27, 55, 52, 56, 42, 60, 44, 33, 47, 46, 63, 43, 43, 52, 38, 44, 31, 60, 61, 41, 46, 28, 19, 41, 24, 42, 27, 26]

# %%
# Crear un DataFrame con las edades
df = pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     20
# 1     50
# 2     48
# 3     35
# 4     37
# ..   ...
# 95    41
# 96    24
# 97    42
# 98    27
# 99    26
#
# [100 rows x 1 columns]

# %%
# Calcular el número de intervalos utilizando la regla de Sturges
n = len(edades)
K = int( 1 + math.log2(n))
print("Valor de n = ", n , " \nNúmero de intervalos =", K)
# Out:
# Valor de n =  100
# Número de intervalos = 7

# %%
# Crear la tabla de frecuencia

tabla_frecuencia = pd.cut( df['Edad'], bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (40.857, 48.143]    27
# 1  (26.286, 33.571]    16
# 2  (48.143, 55.429]    14
# 3  (33.571, 40.857]    13
# 4  (18.948, 26.286]    12
# 5    (62.714, 70.0]    10
# 6  (55.429, 62.714]     8

# %%
# Ordenar la tabla de frecuencia por el intervalo
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 4  (18.948, 26.286]    12
# 1  (26.286, 33.571]    16
# 3  (33.571, 40.857]    13
# 0  (40.857, 48.143]    27
# 2  (48.143, 55.429]    14
# 6  (55.429, 62.714]     8
# 5    (62.714, 70.0]    10

# %%
# Generar columnas siguientes
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

# Mostrar la tabla de frecuencia
print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 4  (18.948, 26.286]    12      0.12       12.0       12         0.12
# 1  (26.286, 33.571]    16      0.16       16.0       28         0.28
# 3  (33.571, 40.857]    13      0.13       13.0       41         0.41
# 0  (40.857, 48.143]    27      0.27       27.0       68         0.68
# 2  (48.143, 55.429]    14      0.14       14.0       82         0.82
# 6  (55.429, 62.714]     8      0.08        8.0       90         0.90
# 5    (62.714, 70.0]    10      0.10       10.0      100         1.00
#
#    Frec Porc Ac
# 4          12.0
# 1          28.0
# 3          41.0
# 0          68.0
# 2          82.0
# 6          90.0
# 5         100.0

# %%
plt.hist(edades, alpha = 0.5)
plt.title("Histograma de edades basado en la funcion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion de matplotlib con valores estandar')

# %%
# Crear un histograma basado en la tabla de frecuencia

plt.hist(df['Edad'], bins=K, alpha = 0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ### Medidas de tendencia central
# ### CAPITULO 3  LIBRO ESTADISTICA PARA ADMINISTRACION
#
# Media aritmética, geométrica y ponderada, Mediana, Moda, Medidas de
# dispersión, Varianza, Desviación estándar, Desviación media, Desviación mediana

# %% [markdown]
# ### La media geométrica
# 1. indica la tendencia central o valor típico de LOS DATOS utilizando el producto de los valores (en oposición a la media aritmética, que utiliza su suma).

# %%
print(edades)
# Out:
# [20, 50, 48, 35, 37, 54, 59, 63, 36, 46, 40, 52, 20, 20, 55, 65, 40, 30, 37, 48, 19, 32, 39, 53, 31, 49, 49, 29, 68, 66, 62, 60, 70, 52, 52, 28, 47, 29, 21, 68, 64, 35, 54, 40, 30, 29, 42, 56, 45, 47, 47, 29, 37, 31, 29, 21, 47, 69, 47, 42, 22, 19, 34, 44, 46, 23, 53, 37, 41, 66, 45, 44, 27, 55, 52, 56, 42, 60, 44, 33, 47, 46, 63, 43, 43, 52, 38, 44, 31, 60, 61, 41, 46, 28, 19, 41, 24, 42, 27, 26]

# %%
maximo = max(edades)
minimo = min(edades)
rango = maximo - minimo
media = mean(edades)
mediana = median(edades)
moda = mode(edades)

print( "Estadistica descriptiva de la Fabrica 1 \n", "Media =", media,
     "\n Mediana =", mediana, "\n Moda =", moda, "\n Maximo = ", maximo,
     "\n Minimo =", minimo, "\n Rango =", rango)

media_geometrica = geometric_mean(edades)
print("media_geometrica", media_geometrica)

# Una alta varianza indica que los datos están dispersos; una baja varianza indica que
# los datos están agrupados estrechamente alrededor de la media.
varianza = variance(edades)
print("Varianza", varianza)

varianza_poblacional = pvariance(edades)
print("varianza_poblacional", varianza_poblacional)

desviacion_estandar = stdev(edades)
print("desviacion_estandar", desviacion_estandar)

desviacion_poblacional = pstdev(edades)
print("desviacion_poblacional", desviacion_poblacional)
# Out:
# Estadistica descriptiva de la Fabrica 1
#  Media = 42.85
#  Mediana = 43.5
#  Moda = 47
#  Maximo =  70
#  Minimo = 19
#  Rango = 51
# media_geometrica 40.54450345299135
# Varianza 184.08838383838383
# varianza_poblacional 182.2475
# desviacion_estandar 13.56791744662326
# desviacion_poblacional 13.499907407089871

# %% [markdown]
# ## La media ponderada
#
# 1. permite calcular un promedio que toma en cuenta la importancia de cada valor con respecto al total

# %% [markdown]
# ### statistics.fmean(data, weights=None)
#
# 1. Convierte los valores de data a flotantes y calcula la media aritmética.
# 2. La ponderación es opcional.
# 3. Por ejemplo, un profesor asigna una nota a un curso ponderando las pruebas en un 20%, los deberes en un 20%, un examen parcial en un 30% y un examen final en un 30%:

# %%
grades = [85, 92, 83, 91]
weights = [0.20, 0.20, 0.30, 0.30]

fmean(grades, weights)
# Out:
# 87.6

# %%
help(fmean)
# Out:
# Help on function fmean in module statistics:
#
# fmean(data, weights=None)
#     Convert data to floats and compute the arithmetic mean.
#
#     This runs faster than the mean() function and it always returns a float.
#     If the input dataset is empty, it raises a StatisticsError.
#
#     >>> fmean([3.5, 4.0, 5.25])
#     4.25

# %% [markdown]
# ### 9. Diagrama de Cajas y bigotes <a id="id9"> </a>
#
# 1. Las líneas se usan para indicar la variabilidad fuera de los cuartiles superior e inferior.
# 2. Los valores atípicos se representan a veces como puntos individuales que están en línea con los bigotes.
# 3.  **Si los datos son simétricos, la mediana estará en el centro de la caja**.
# 4. Si los datos están **sesgados**, la mediana estará más cerca de la parte superior o inferior de la caja.
# 5. Los extremos de arriba y abajo de la caja indican los **cuantiles, o percentiles, 25 y 75**. Estos dos cuantiles también se conocen como cuartiles, porque separan cuartos (25 %) de los datos. La longitud de la caja es la diferencia entre estos dos percentiles y se conoce como rango intercuartílico (IQR)
# 6. Los diagramas caja-bigotes son muy útiles para comparar dos o más conjuntos de datos.
#
# https://www.jmp.com/es_mx/statistics-knowledge-portal/exploratory-data-analysis/box-plot.html#:~:text=Los%20extremos%20de%20arriba%20y,como%20rango%20intercuart%C3%ADlico%20(IQR).

# %%
print(fabrica1)
# Out:
# [75.09, 72.95, 81.54, 57.59, 71.25, 82.33, 74.27, 85.48, 53.74, 53.1, 86.72, 57.46, 71.57, 65.05, 79.93, 79.7, 96.01, 84.38, 82.93, 98.15, 53.68, 76.45, 98.49, 93.33, 81.41, 61.73, 67.9, 51.6, 79.93, 65.43, 55.86, 57.24, 82.47, 55.09, 78.45, 95.29, 94.35, 66.77, 58.71, 86.9, 98.56, 76.16, 97.21, 63.96, 91.24, 61.1, 85.86, 87.16, 54.08, 52.86, 63.41, 69.02, 98.1, 69.2, 91.92, 79.27, 56.82, 94.86, 70.92, 84.86, 53.79, 63.29, 98.36, 66.46, 75.12, 80.42, 82.75, 71.2, 57.7, 77.65, 63.84, 98.42, 91.05, 82.97, 93.15, 76.85, 62.0, 50.63, 70.94, 63.83, 91.76, 63.39, 76.65, 86.88, 56.34, 85.89, 58.52, 65.22, 80.31, 50.33, 85.44, 59.93, 71.42, 56.26, 77.58, 84.81, 73.19, 85.22, 88.33, 50.69]

# %%
plt.boxplot(fabrica1)
plt.ylabel('Edades')
# https://matplotlib.org/stable/gallery/text_labels_and_annotations/accented_text.html#sphx-glr-gallery-text-labels-and-annotations-accented-text-py
plt.text(.8, 145, 'Dato Atípico')
plt.title('Produccion fabrica 1')
plt.show()

# %% [markdown]
# https://www.youtube.com/watch?v=24Uz1mBksL4

# %% [markdown]
# ### Comparamos la producción de la fabrica 1 y 2 en un subplot

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))

bplot1 = ax1.boxplot(fabrica1,
                     vert=True,  # vertical box alignment
                     patch_artist=True)  # fill with color
ax1.set_title('Producción fabrica 1')

bplot2 = ax2.boxplot(fabrica2,
                     vert=True,  # vertical box alignment
                     patch_artist=True)  # fill with color

ax2.set_title('Produccion fabrica 2')

plt.show()

# %% [markdown]
# ### Conclusiones

# %%
# Insertamos un valor de 150 a la fabrica 1,
# Seíra un valor atipico

fabrica1.append(150)
print(fabrica1)
# Out:
# [75.09, 72.95, 81.54, 57.59, 71.25, 82.33, 74.27, 85.48, 53.74, 53.1, 86.72, 57.46, 71.57, 65.05, 79.93, 79.7, 96.01, 84.38, 82.93, 98.15, 53.68, 76.45, 98.49, 93.33, 81.41, 61.73, 67.9, 51.6, 79.93, 65.43, 55.86, 57.24, 82.47, 55.09, 78.45, 95.29, 94.35, 66.77, 58.71, 86.9, 98.56, 76.16, 97.21, 63.96, 91.24, 61.1, 85.86, 87.16, 54.08, 52.86, 63.41, 69.02, 98.1, 69.2, 91.92, 79.27, 56.82, 94.86, 70.92, 84.86, 53.79, 63.29, 98.36, 66.46, 75.12, 80.42, 82.75, 71.2, 57.7, 77.65, 63.84, 98.42, 91.05, 82.97, 93.15, 76.85, 62.0, 50.63, 70.94, 63.83, 91.76, 63.39, 76.65, 86.88, 56.34, 85.89, 58.52, 65.22, 80.31, 50.33, 85.44, 59.93, 71.42, 56.26, 77.58, 84.81, 73.19, 85.22, 88.33, 50.69, 150]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))

bplot1 = ax1.boxplot(fabrica1,
                     vert=True,  # vertical box alignment
                     patch_artist=True)  # fill with color
ax1.set_title('Producción fabrica 1')

bplot2 = ax2.boxplot(fabrica2,
                     vert=True,  # vertical box alignment
                     patch_artist=True)  # fill with color

ax2.set_title('Producción fabrica 2')

plt.show()
