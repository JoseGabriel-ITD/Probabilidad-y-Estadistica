# %% [markdown]
# <a href="https://colab.research.google.com/github/JoseGabriel-ITD/Probabilidad-y-Estadistica/blob/main/Programa1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# # Probabilidad y estadistica
#
# ## Unidad 1
#
# ### Grupo: **2Z**
#
# ### Practica 0. Introduccion a Python
#
# Alumno: _______________________
#
# Docente: Dr. José Gabriel Rodríguez Rivas

# %%
x = 10
print(x)
# Out:
# 10

# %%
print( type(x))
# Out:
# <class 'int'>

# %%
x = "hola"
print (x)
# Out:
# hola

# %%
print( type(x))
# Out:
# <class 'str'>

# %%
a = 12
b = 25
if a > b:
    print( a, "es mayor que", b)
else:
    print(b, 'es mayor que', a)
# Out:
# 25 es mayor que 12

# %%
# esto es un comentario
for i in range(10):
    print(i)
    print("Hola", i)
print("Fuera del for")
# Out:
# 0
# Hola 0
# 1
# Hola 1
# 2
# Hola 2
# 3
# Hola 3
# 4
# Hola 4
# 5
# Hola 5
# 6
# Hola 6
# 7
# Hola 7
# 8
# Hola 8
# 9
# Hola 9
# Fuera del for
